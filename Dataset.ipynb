# %%
import twint
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import nest_asyncio
nest_asyncio.apply()

plt.style.use('fivethirtyeight')


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import re
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()

import datetime
since = datetime.datetime(2020, 5, 5)
until = datetime.datetime(2022, 5, 5)

# %%
c = twint.Config()

c.Search = ['Covid-19','Education']
c.Lang="en"
c.Store_csv = True    
c.Output = "Covid19Edu.csv" 

twint.run.Search(c)
# Out:
# 1523788049368317952 2022-05-10 01:12:36 +0300 <EducationNews_b> NYC lifts student vaccine mandate for prom (New York Post)  New York City public school students no longer have to be vaccinated against COVID-19 to att...  Add your highlights:  https://t.co/weU3LnGHW7  #Education
# 1523785183199117315 2022-05-10 01:01:12 +0300 <EsayWriter> A Contemporary Issue Relating To Covid 19 In Early Childhood Education. To critically examine a contemporary issue,  https://t.co/YXIPSndIlD
# 1523783833660780544 2022-05-10 00:55:51 +0300 <MadmoiZelleqc> Projet de loi de l'Ontario 12 Loi édictant la Loi de 2021 sur les vaccinations obligatoires contre la COVID-19 dans les secteurs de l'éducation et des soins de santé   https://t.co/BU1tbtmi2E
# ...

# %%
c = twint.Config()

c.Search = ['Covid','Education']
c.Lang="en"
c.Store_csv = True    
c.Output = "CovidEdu.csv" 

twint.run.Search(c)
# Out:
# 1523793670834597888 2022-05-10 01:34:56 +0300 <ric4100> Thank God Florida had @GovRonDeSantis as the Governor during the pandemic. A report on education of our children during Covid, shows that Florida &amp; Texas poor &amp; middle class children DID NOT LOSE ANY GROUND ON EDUCATION because they STAYED OPEN. The worst states were locked down  https://t.co/bEa83Q7lIP
# 1523792605628321793 2022-05-10 01:30:42 +0300 <SpeakerBoXX08> My goal was to get my VA license by 12/31/2021.. then got busy building the team but having Covid at the end of the year slowed me down to at least start the process  it definitely wasn’t easy and now I gotta do 30 hrs of post licensing education 😩
# ...

# %%
c = twint.Config()

c.Search = ['Pandemic','Education']
c.Lang="en"
c.Store_csv = True    
c.Output = "PandemicEdu.csv" 

twint.run.Search(c)
# Out:
# 1523796574697975808 2022-05-10 01:46:28 +0300 <RealsmithJ> @BrockWHarrison @RachelNotley Remember that time when the government crippled the access of public education to the kids that needed it most during one of the most intense periods of the pandemic. Through a social media post no less! That was fun…  https://t.co/pS31Ef7nQH
# 1523795862182567936 2022-05-10 01:43:38 +0300 <theabcsofmissv> TOGETHER WE CAN become Masters of Education through a global pandemic!  https://t.co/zJyfgNRzjn
# 1523795135938527232 2022-05-10 01:40:45 +0300 <MCola34> @MikeCarlton01 Wow.We are doing well on the global stage. Rating high for pandemic spread. Yet low on education ranking. Insulting France. Ignoring Solomon’s islands. Inflaming China. Pandering to USA’s interests before our own.Having a poor or insignificant climate change plan .. #auspol
# ...

# %%
c = twint.Config()

c.Search = ['Corona','Education']
c.Lang="en"
c.Store_csv = True    
c.Output = "CoronEdu.csv" 

twint.run.Search(c)
# Out:
# 1523737422445826048 2022-05-09 21:51:25 +0300 <holuraf_> 9 months Asuu strike  in 2020 + Corona and now going to 6 months of another ASUU strike in 2022 💔💔💔 what is now the value of Education in this country 🤦‍♂️🤦‍♂️
# 1523720425343426560 2022-05-09 20:43:53 +0300 <0kitkatt> Corona is back and just realised that shafqat mehmood is no more our education minister 🥲
# 1523695159783092225 2022-05-09 19:03:29 +0300 <namanapple> @mandeepggs @me_akshit @UnivofDelhi @DDMADelhi1 @msisodia @AAPDelhi @ArvindKejriwal @JarnailSinghAAP @Minister_Edu @Dir_Education @ANI If corona spreads, it is already spreading but who cares unless someone dies
# 1523685874156056576 2022-05-09 18:26:35 +0300 <GhazanfarChee14> @AarbiiSayss Hahahahaha NAI honay Chahiye education Ka bayra gharak Kar Diya es CORONA na-muraad nain
# ...

# %%
c = twint.Config()

c.Search = ['Covid','Education','Online']
c.Lang="en"
c.Store_csv = True    
c.Output = "CovidEdu.csv" 

twint.run.Search(c)
# Out:
# 1523742110884761601 2022-05-09 22:10:03 +0300 <MarketsCafe> West Bengal Colleges Go Online Again After State Governments Diktat Over Heat Online education system picked up in India as well as in other countries soon after the Covid-19 pandemic hit the world #India by #News18  https://t.co/jaCkcU7E5P
# 1523741778607628288 2022-05-09 22:08:44 +0300 <TheNextTech2018> Importance of Online Education Platforms After the Covid-19  https://t.co/CKVRDF94qR #digitalknowledge #digitaltechnology #elearning #educationalsystem #itstructure #onlinecourse #onlineeducationplatforms #onlinelearning #remoteplatforms #sociallearning #socialmedia #tnt2022
# 1523731929702445056 2022-05-09 21:29:36 +0300 <FeralHeather> @dailycal Why aren’t professors planning online options into their courses? We are two years into this thing, and these are allegedly intelligent people; all students, including disabled students at high risk for severe COVID, deserve equal access to education.
# ...

# %%
c = twint.Config()

c.Search = ['Online','Exam','Covid']
c.Lang="en"
c.Store_csv = True    
c.Output = "CovidExam.csv" 

twint.run.Search(c)
# Out:
# 1523748280668016640 2022-05-09 22:34:34 +0300 <manojkumarvais> RGPV ONLINE EXAM Reason:1. COVID -19  ka 4th wave aa raha hai aur hamare desh aur State me lagatar COVID case badh rahe hai.2. College me 6 month ka course  1.5-2 month me kaise complete ho sakta hai #Rgpvonlineexams #RgpvStudentsDemandsOnlineExam #rgpv_online_exam  @GopilKotwal
# 1523726982311137281 2022-05-09 21:09:56 +0300 <MehrozSultan1> Respected Sir, we are students of (statistics/mathematics) and it is extremely difficult for us to study online, we were never in favour of online classes during Ramadan. It was an unjust decision for us. We already struggled alot during COVID because of online exams.(2) @zaidia
# ...

# %%
df=pd.read_csv('Covid-19Edu.csv')
df.head()
# Out:
#                     id      conversation_id  \
# 0  1523788049368317952  1523788049368317952
# 1  1523785183199117315  1523785183199117315
# 2  1523783833660780544  1523783833660780544
# 3  1523782220649017346  1523782220649017346
# 4  1523767854507565056  1523767854507565056
#
#                                    created_at        date      time  timezone  \
# 0  2022-05-10 01:12:36 Türkiye Standart Saati  2022-05-10  01:12:36       300
# 1  2022-05-10 01:01:12 Türkiye Standart Saati  2022-05-10  01:01:12       300
# 2  2022-05-10 00:55:51 Türkiye Standart Saati  2022-05-10  00:55:51       300
# 3  2022-05-10 00:49:26 Türkiye Standart Saati  2022-05-10  00:49:26       300
# 4  2022-05-09 23:52:21 Türkiye Standart Saati  2022-05-09  23:52:21       300
#
#                user_id         username  \
# 0           2872659972  educationnews_b
# 1  1285518231906787328       esaywriter
# 2   746860686387585025    madmoizelleqc
# 3             20052710             wlrn
# ...

# %%
df.drop(['id','conversation_id','created_at','date','time','timezone','user_id','place','language','mentions','urls','photos','replies_count','retweets_count','likes_count','hashtags','cashtags','link','retweet','quote_url','video','thumbnail','near','geo','source','user_rt_id','user_rt','retweet_id','reply_to','retweet_date','translate','trans_src','trans_dest'],axis = 1, inplace = True)

# %%
df.head()
# Out:
#           username                                   name  \
# 0  educationnews_b                      Education Briefly
# 1       esaywriter                       Essay Writer👨‍🎓👌
# 2    madmoizelleqc                                Melissa
# 3             wlrn                      WLRN Public Media
# 4   langleylocalip  Langley Local Immigration Partnership
#
#                                                tweet
# 0  NYC lifts student vaccine mandate for prom (Ne...
# 1  A Contemporary Issue Relating To Covid 19 In E...
# 2  Projet de loi de l'Ontario 12 Loi édictant la ...
# 3  Notable this year: @Ovalle_LJ, producer of @WL...
# 4  Advocates say situations like Thirukkumaran's ...

# %%
Corona_df=pd.read_csv('CoronEdu.csv')
Corona_df.head()
# Out:
#                     id      conversation_id  \
# 0  1523737422445826048  1523737422445826048
# 1  1523720425343426560  1523720425343426560
# 2  1523695159783092225  1523577402915311622
# 3  1523685874156056576  1523683965277663235
# 4  1523608543638679552  1523608543638679552
#
#                                    created_at        date      time  timezone  \
# 0  2022-05-09 21:51:25 Türkiye Standart Saati  2022-05-09  21:51:25       300
# 1  2022-05-09 20:43:53 Türkiye Standart Saati  2022-05-09  20:43:53       300
# 2  2022-05-09 19:03:29 Türkiye Standart Saati  2022-05-09  19:03:29       300
# 3  2022-05-09 18:26:35 Türkiye Standart Saati  2022-05-09  18:26:35       300
# 4  2022-05-09 13:19:18 Türkiye Standart Saati  2022-05-09  13:19:18       300
#
#                user_id         username                name  place  ... geo  \
# 0            371365012         holuraf_  leader of tomorrow    NaN  ... NaN
# ...

# %%
Corona_df.drop(['id','conversation_id','created_at','date','time','timezone','user_id','place','language','mentions','urls','photos','replies_count','retweets_count','likes_count','hashtags','cashtags','link','retweet','quote_url','video','thumbnail','near','geo','source','user_rt_id','user_rt','retweet_id','reply_to','retweet_date','translate','trans_src','trans_dest'],axis = 1, inplace = True)

# %%
Corona_df.head()
# Out:
#           username                name  \
# 0         holuraf_  leader of tomorrow
# 1         0kitkatt              Hamna🌸
# 2       namanapple        Naman Juneja
# 3  ghazanfarchee14    Ghazanfar Cheema
# 4    madhu64103522  i am a lucky loser
#
#                                                tweet
# 0  9 months Asuu strike  in 2020 + Corona and now...
# 1  Corona is back and just realised that shafqat ...
# 2  @mandeepggs @me_akshit @UnivofDelhi @DDMADelhi...
# 3  @AarbiiSayss Hahahahaha NAI honay Chahiye educ...
# 4  @SoodFoundation Hi sir. I will be in Nellore. ...

# %%
Covid_df=pd.read_csv('CovidEdu.csv')

# %%
Covid_df.drop(['id','conversation_id','created_at','date','time','timezone','user_id','place','language','mentions','urls','photos','replies_count','retweets_count','likes_count','hashtags','cashtags','link','retweet','quote_url','video','thumbnail','near','geo','source','user_rt_id','user_rt','retweet_id','reply_to','retweet_date','translate','trans_src','trans_dest'],axis = 1, inplace = True)

# %%
Covid_df.head()
# Out:
#         username              name  \
# 0        ric4100          Ric Paul
# 1  speakerboxx08               Rue
# 2     wetm18news           WETM-TV
# 3   phoenixashes        Alex Swaim
# 4  cornwall70001  Cornwall7000 ⛵️🐕
#
#                                                tweet
# 0  Thank God Florida had @GovRonDeSantis as the G...
# 1  My goal was to get my VA license by 12/31/2021...
# 2  Since the pandemic, New York's health care sys...
# 3  *looks at one of the Grapevine ISD races*  The...
# 4  @William92786781 @YisraelChaiAdam @BenKentish ...

# %%
CovidE_df=pd.read_csv('CovidExam.csv')

# %%
CovidE_df.drop(['id','conversation_id','created_at','date','time','timezone','user_id','place','language','mentions','urls','photos','replies_count','retweets_count','likes_count','hashtags','cashtags','link','retweet','quote_url','video','thumbnail','near','geo','source','user_rt_id','user_rt','retweet_id','reply_to','retweet_date','translate','trans_src','trans_dest'],axis = 1, inplace = True)

# %%
CovidE_df.head()
# Out:
#          username              name  \
# 0  manojkumarvais    Er. Manoj Bais
# 1   mehrozsultan1     Mehroz Sultan
# 2   therealobioma                oh
# 3      arabvibage        first lady
# 4       symtwittt  sym accidentally
#
#                                                tweet
# 0  RGPV ONLINE EXAM Reason:1. COVID -19  ka 4th w...
# 1  Respected Sir, we are students of (statistics/...
# 2  The COVID year where we had substandard online...
# 3                   thank you covid for online exams
# 4  @Bukan_NamaBetul @najihahshahrel Kenapa waktu ...

# %%
Pandemic_df=pd.read_csv('PandemicEdu.csv')

# %%
Pandemic_df.drop(['id','conversation_id','created_at','date','time','timezone','user_id','place','language','mentions','urls','photos','replies_count','retweets_count','likes_count','hashtags','cashtags','link','retweet','quote_url','video','thumbnail','near','geo','source','user_rt_id','user_rt','retweet_id','reply_to','retweet_date','translate','trans_src','trans_dest'],axis = 1, inplace = True)

# %%
Pandemic_df.head()
# Out:
#          username                                    name  \
# 0      realsmithj                             Jason Smith
# 1  theabcsofmissv                        Taylor Vollstedt
# 2         mcola34                                     mia
# 3         ric4100                                Ric Paul
# 4   janicekayephd  Janice Kaye🇨🇦 Ph.D.🇺🇸 Vax💉💉💉Mask😷 🇺🇦 🟩
#
#                                                tweet
# 0  @BrockWHarrison @RachelNotley Remember that ti...
# 1  TOGETHER WE CAN become Masters of Education th...
# 2  @MikeCarlton01 Wow.We are doing well on the gl...
# 3  Thank God Florida had @GovRonDeSantis as the G...
# 4  Needs an education in how the virus is spread....

# %%
df_row_reindex = pd.concat([Pandemic_df,CovidE_df,Covid_df,Corona_df, df], ignore_index=True)

df_row_reindex
# Out:
#             username                                    name  \
# 0         realsmithj                             Jason Smith
# 1     theabcsofmissv                        Taylor Vollstedt
# 2            mcola34                                     mia
# 3            ric4100                                Ric Paul
# 4      janicekayephd  Janice Kaye🇨🇦 Ph.D.🇺🇸 Vax💉💉💉Mask😷 🇺🇦 🟩
# ...              ...                                     ...
# 6241          phkule                    Philippine Collegian
# 6242   uobedresearch        Education Research at Birmingham
# 6243   friedbergeric                       Eric Friedberg MD
# 6244  moms4edfreedom              Moms for #EducationFreedom
# 6245       dijahjawo                              _____Dijah
#
#                                                   tweet
# 0     @BrockWHarrison @RachelNotley Remember that ti...
# 1     TOGETHER WE CAN become Masters of Education th...
# 2     @MikeCarlton01 Wow.We are doing well on the gl...
# ...

# %%
Covid19Education_tweets_df = df_row_reindex.drop_duplicates()

# %%
export_csv = Covid19Education_tweets_df.to_csv(r'Covid19Education_tweets_final.csv')
